# %%
import numpy as np
import matplotlib.pyplot as plt

# 送信側アンテナ数
M = 1

# 送信ビット数
#bit_num = 12 * 10 ** 5
bit_num = 12 * 10 ** 2

EbNo_min = 0
EbNo_max = 20
freq = 21
power_range = np.linspace(EbNo_min, EbNo_max, freq)


for EbNo in power_range:
    TX_bit = np.random.randint(0, 64, (M, bit_num))


fig1 = plt.figure(figsize = (7,3), facecolor='lightblue')

ax1_1 = fig1.add_subplot(1, 1, 1)
ax1_1.set_title("Pseudo Random Binary Signal")
ax1_1.plot(TX_bit, ".-")

print(TX_bit)
print(np.size(TX_bit))

binary_representation = bin(TX_bit[0,:])
# Out:
# [[13 58 35 ... 21 45  5]]
# 1200
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 30
#      27 print(TX_bit)
#      28 print(np.size(TX_bit))
# ---> 30 binary_representation = bin(TX_bit[0,:])
#
# TypeError: only integer scalar arrays can be converted to a scalar index
